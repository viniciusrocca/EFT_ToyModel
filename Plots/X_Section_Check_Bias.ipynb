# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import random
import math
from auxPlots import selectColor, xSecTest
from aux import getInfo, getLHEevents, getDistributions


pd.option_context('display.max_columns', -1)

pd.options.mode.chained_assignment = None #Disable copy warnings
# plt.style.use('fivethirtyeight') #Set style
# mpl.rcParams.update({'figure.figsize' : (15,10)})  #Set general plotting options
plt.rcParams['figure.max_open_warning'] = 50
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

plt.rcParams.update({"savefig.dpi" : 300}) #Figure resolution


#Define plotting style:
sns.set() #Set style
sns.set_style('ticks',{'font.family':'Times New Roman', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=1.8)
cm = plt.colormaps['RdYlBu']

# %%
#Reading bias files
files = list(glob.glob('/home/vinicius/EFT_ToyModel/processFolders/Distributions/bias/*/*/*.npz'))
data_b = []
#Loading the distributions
for f in files:
    aux = np.load(f, allow_pickle = True)
    data_b.append(aux)

data_b = sorted(data_b, key=lambda d: d['mass_params'][0])

print(data_b[4]['deltaPhi'], data_b[5]['model'])
# Out:
# [3.14159265 3.14159265 3.14159265 ... 3.14159265 3.14159265 3.14159265] EFT

# %%
#Reading no bias files
files = list(glob.glob('/home/vinicius/EFT_ToyModel/processFolders/Distributions/*/*/*.npz'))
data = []
data_sm = []
#Loading the distributions
for f in files:
    aux = np.load(f, allow_pickle = True)
    if aux['model'] == 'SM':
        data_sm.append(aux)
    else:
        data.append(aux)

data = sorted(data, key=lambda d: d['mass_params'][0])
print(data_sm[2]['process'])
print(data[4]['deltaPhi'], data[5]['model'])
# Out:
# $p p \to t \bar{t}$
# [3.14159265 3.14159265 3.14159265 ... 3.14159265 3.14159265 3.14159265] EFT

# %%
a = 0.409322124
b = 0.405000000
diff = abs(a-b)
rel_tol = 1e-1
x = rel_tol * max(abs(a), abs(b))
print(diff, x)
# Out:
# 0.004322123999999983 0.0409322124

# %%
display = True
for i,d in enumerate(data):
    mPsiT,mSDM = d['mass_params']
    
    a = abs((d['xsec (pb)']-data_b[i]['xsec (pb)'])/d['xsec (pb)'])
    b = abs((sum(data_b[i]['weights']) - sum(d['weights'] ))/sum(d['weights'] ))
    #print(a,b)
    if abs((d['xsec (pb)']-data_b[i]['xsec (pb)'])/d['xsec (pb)']) < 0.05 and abs((sum(data_b[i]['weights']) - sum(d['weights'] ))/sum(d['weights'] )) < 0.05:
        print(d['model'], d['process'], ' mPsiT: %.1f, mSDM: %.1f' % (mPsiT,mSDM), 'Result: APROVED')
    else:
        print(d['model'], d['process'], ' mPsiT: %.1f, mSDM: %.1f' % (mPsiT,mSDM), 'Result: REPROVED')

    if display == True:
            print('No bias: xsec = %.9f sum of weights = %.9f bias: xsec = %.9f sum of weights = %.9f' % (d['xsec (pb)'], sum(d['weights'] ), data_b[i]['xsec (pb)'], sum(data_b[i]['weights'])))
    print()
# Out:
# EFT $g g \to t \bar{t}$  mPsiT: 200.0, mSDM: 190.0 Result: APROVED
# No bias: xsec = 0.447441000 sum of weights = 0.447441000 bias: xsec = 0.448410520 sum of weights = 0.448410524
#
# EFT $q q \to t \bar{t}$  mPsiT: 200.0, mSDM: 190.0 Result: APROVED
# No bias: xsec = 0.414310000 sum of weights = 0.414310000 bias: xsec = 0.411134550 sum of weights = 0.411134551
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 200.0, mSDM: 190.0 Result: APROVED
# No bias: xsec = 0.957268227 sum of weights = 0.957268227 bias: xsec = 0.957700000 sum of weights = 0.957700000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 200.0, mSDM: 190.0 Result: APROVED
# No bias: xsec = 0.441245229 sum of weights = 0.441245229 bias: xsec = 0.438900000 sum of weights = 0.438900000
#
# EFT $g g \to t \bar{t}$  mPsiT: 300.0, mSDM: 285.0 Result: APROVED
# No bias: xsec = 0.198857600 sum of weights = 0.198857600 bias: xsec = 0.199104380 sum of weights = 0.199104381
#
# EFT $q q \to t \bar{t}$  mPsiT: 300.0, mSDM: 285.0 Result: APROVED
# No bias: xsec = 0.184136000 sum of weights = 0.184136000 bias: xsec = 0.183055000 sum of weights = 0.183055003
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 300.0, mSDM: 285.0 Result: APROVED
# No bias: xsec = 0.409322124 sum of weights = 0.409322124 bias: xsec = 0.405000000 sum of weights = 0.405000000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 300.0, mSDM: 285.0 Result: APROVED
# No bias: xsec = 0.249462897 sum of weights = 0.249462897 bias: xsec = 0.250900000 sum of weights = 0.250900000
#
# EFT $g g \to t \bar{t}$  mPsiT: 400.0, mSDM: 380.0 Result: APROVED
# No bias: xsec = 0.111859700 sum of weights = 0.111859700 bias: xsec = 0.111994830 sum of weights = 0.111994828
#
# EFT $q q \to t \bar{t}$  mPsiT: 400.0, mSDM: 380.0 Result: APROVED
# No bias: xsec = 0.103576000 sum of weights = 0.103576000 bias: xsec = 0.102967340 sum of weights = 0.102967339
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 400.0, mSDM: 380.0 Result: APROVED
# No bias: xsec = 0.178870147 sum of weights = 0.178870147 bias: xsec = 0.178300000 sum of weights = 0.178300000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 400.0, mSDM: 380.0 Result: APROVED
# No bias: xsec = 0.134940210 sum of weights = 0.134940210 bias: xsec = 0.134700000 sum of weights = 0.134700000
#
# EFT $g g \to t \bar{t}$  mPsiT: 500.0, mSDM: 475.0 Result: APROVED
# No bias: xsec = 0.071589800 sum of weights = 0.071589800 bias: xsec = 0.071733184 sum of weights = 0.071733184
#
# EFT $q q \to t \bar{t}$  mPsiT: 500.0, mSDM: 475.0 Result: APROVED
# No bias: xsec = 0.066289000 sum of weights = 0.066289000 bias: xsec = 0.065900392 sum of weights = 0.065900392
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 500.0, mSDM: 475.0 Result: APROVED
# No bias: xsec = 0.098850282 sum of weights = 0.098850282 bias: xsec = 0.097680000 sum of weights = 0.097680000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 500.0, mSDM: 475.0 Result: APROVED
# No bias: xsec = 0.081606587 sum of weights = 0.081606587 bias: xsec = 0.081660000 sum of weights = 0.081660000
#
# EFT $g g \to t \bar{t}$  mPsiT: 600.0, mSDM: 570.0 Result: APROVED
# No bias: xsec = 0.049715300 sum of weights = 0.049715300 bias: xsec = 0.049815707 sum of weights = 0.049815707
#
# EFT $q q \to t \bar{t}$  mPsiT: 600.0, mSDM: 570.0 Result: APROVED
# No bias: xsec = 0.046035000 sum of weights = 0.046035000 bias: xsec = 0.045763643 sum of weights = 0.045763643
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 600.0, mSDM: 570.0 Result: APROVED
# No bias: xsec = 0.062288298 sum of weights = 0.062288298 bias: xsec = 0.061630000 sum of weights = 0.061630000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 600.0, mSDM: 570.0 Result: APROVED
# No bias: xsec = 0.054321553 sum of weights = 0.054321553 bias: xsec = 0.054160000 sum of weights = 0.054160000
#
# EFT $g g \to t \bar{t}$  mPsiT: 700.0, mSDM: 665.0 Result: APROVED
# No bias: xsec = 0.036525000 sum of weights = 0.036525000 bias: xsec = 0.036595405 sum of weights = 0.036595405
#
# EFT $q q \to t \bar{t}$  mPsiT: 700.0, mSDM: 665.0 Result: APROVED
# No bias: xsec = 0.033821000 sum of weights = 0.033821000 bias: xsec = 0.033621687 sum of weights = 0.033621687
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 700.0, mSDM: 665.0 Result: APROVED
# No bias: xsec = 0.042924456 sum of weights = 0.042924456 bias: xsec = 0.042860000 sum of weights = 0.042860000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 700.0, mSDM: 665.0 Result: APROVED
# No bias: xsec = 0.038704574 sum of weights = 0.038704574 bias: xsec = 0.038580000 sum of weights = 0.038580000
#
# EFT $g g \to t \bar{t}$  mPsiT: 800.0, mSDM: 760.0 Result: APROVED
# No bias: xsec = 0.027964400 sum of weights = 0.027964400 bias: xsec = 0.028022763 sum of weights = 0.028022763
#
# EFT $q q \to t \bar{t}$  mPsiT: 800.0, mSDM: 760.0 Result: APROVED
# No bias: xsec = 0.025894100 sum of weights = 0.025894100 bias: xsec = 0.025742268 sum of weights = 0.025742268
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 800.0, mSDM: 760.0 Result: APROVED
# No bias: xsec = 0.031898900 sum of weights = 0.031898900 bias: xsec = 0.031860000 sum of weights = 0.031860000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 800.0, mSDM: 760.0 Result: APROVED
# No bias: xsec = 0.028936035 sum of weights = 0.028936035 bias: xsec = 0.028700000 sum of weights = 0.028700000
#
# EFT $g g \to t \bar{t}$  mPsiT: 900.0, mSDM: 855.0 Result: APROVED
# No bias: xsec = 0.022095680 sum of weights = 0.022095680 bias: xsec = 0.022139137 sum of weights = 0.022139137
#
# EFT $q q \to t \bar{t}$  mPsiT: 900.0, mSDM: 855.0 Result: APROVED
# No bias: xsec = 0.020459600 sum of weights = 0.020459600 bias: xsec = 0.020339410 sum of weights = 0.020339410
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 900.0, mSDM: 855.0 Result: APROVED
# No bias: xsec = 0.024399384 sum of weights = 0.024399384 bias: xsec = 0.024240000 sum of weights = 0.024240000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 900.0, mSDM: 855.0 Result: APROVED
# No bias: xsec = 0.022331930 sum of weights = 0.022331930 bias: xsec = 0.022320000 sum of weights = 0.022320000
#
# EFT $g g \to t \bar{t}$  mPsiT: 1000.0, mSDM: 950.0 Result: APROVED
# No bias: xsec = 0.017897950 sum of weights = 0.017897950 bias: xsec = 0.017931952 sum of weights = 0.017931952
#
# EFT $q q \to t \bar{t}$  mPsiT: 1000.0, mSDM: 950.0 Result: APROVED
# No bias: xsec = 0.016572300 sum of weights = 0.016572300 bias: xsec = 0.016474712 sum of weights = 0.016474712
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 1000.0, mSDM: 950.0 Result: APROVED
# No bias: xsec = 0.019340984 sum of weights = 0.019340984 bias: xsec = 0.019290000 sum of weights = 0.019290000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 1000.0, mSDM: 950.0 Result: APROVED
# No bias: xsec = 0.017732242 sum of weights = 0.017732242 bias: xsec = 0.017840000 sum of weights = 0.017840000
#
# EFT $g g \to t \bar{t}$  mPsiT: 1250.0, mSDM: 1188.0 Result: APROVED
# No bias: xsec = 0.011453920 sum of weights = 0.011453920 bias: xsec = 0.011477275 sum of weights = 0.011477275
#
# EFT $q q \to t \bar{t}$  mPsiT: 1250.0, mSDM: 1188.0 Result: APROVED
# No bias: xsec = 0.010606300 sum of weights = 0.010606300 bias: xsec = 0.010543878 sum of weights = 0.010543878
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 1250.0, mSDM: 1188.0 Result: APROVED
# No bias: xsec = 0.012009718 sum of weights = 0.012009718 bias: xsec = 0.012050000 sum of weights = 0.012050000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 1250.0, mSDM: 1188.0 Result: APROVED
# No bias: xsec = 0.011100994 sum of weights = 0.011100994 bias: xsec = 0.011100000 sum of weights = 0.011100000
#
# EFT $g g \to t \bar{t}$  mPsiT: 1500.0, mSDM: 1425.0 Result: APROVED
# No bias: xsec = 0.007954380 sum of weights = 0.007954380 bias: xsec = 0.007970457 sum of weights = 0.007970457
#
# EFT $q q \to t \bar{t}$  mPsiT: 1500.0, mSDM: 1425.0 Result: APROVED
# No bias: xsec = 0.007365400 sum of weights = 0.007365400 bias: xsec = 0.007322320 sum of weights = 0.007322321
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 1500.0, mSDM: 1425.0 Result: APROVED
# No bias: xsec = 0.008237281 sum of weights = 0.008237281 bias: xsec = 0.008242000 sum of weights = 0.008242000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 1500.0, mSDM: 1425.0 Result: APROVED
# No bias: xsec = 0.007594877 sum of weights = 0.007594877 bias: xsec = 0.007609000 sum of weights = 0.007609000
#
# EFT $g g \to t \bar{t}$  mPsiT: 2000.0, mSDM: 1900.0 Result: APROVED
# No bias: xsec = 0.004474390 sum of weights = 0.004474390 bias: xsec = 0.004483373 sum of weights = 0.004483373
#
# EFT $q q \to t \bar{t}$  mPsiT: 2000.0, mSDM: 1900.0 Result: APROVED
# No bias: xsec = 0.004143100 sum of weights = 0.004143100 bias: xsec = 0.004111346 sum of weights = 0.004111345
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 2000.0, mSDM: 1900.0 Result: APROVED
# No bias: xsec = 0.004566539 sum of weights = 0.004566539 bias: xsec = 0.004553000 sum of weights = 0.004553000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 2000.0, mSDM: 1900.0 Result: APROVED
# No bias: xsec = 0.004200238 sum of weights = 0.004200238 bias: xsec = 0.004263000 sum of weights = 0.004263000
#
# EFT $g g \to t \bar{t}$  mPsiT: 2500.0, mSDM: 2375.0 Result: APROVED
# No bias: xsec = 0.002863630 sum of weights = 0.002863630 bias: xsec = 0.002857341 sum of weights = 0.002857341
#
# EFT $q q \to t \bar{t}$  mPsiT: 2500.0, mSDM: 2375.0 Result: APROVED
# No bias: xsec = 0.002651560 sum of weights = 0.002651560 bias: xsec = 0.002631387 sum of weights = 0.002631387
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 2500.0, mSDM: 2375.0 Result: APROVED
# No bias: xsec = 0.002904101 sum of weights = 0.002904101 bias: xsec = 0.002896000 sum of weights = 0.002896000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 2500.0, mSDM: 2375.0 Result: APROVED
# No bias: xsec = 0.002675403 sum of weights = 0.002675403 bias: xsec = 0.002619000 sum of weights = 0.002619000
#
# EFT $g g \to t \bar{t}$  mPsiT: 3000.0, mSDM: 2850.0 Result: APROVED
# No bias: xsec = 0.001988572 sum of weights = 0.001988572 bias: xsec = 0.001984267 sum of weights = 0.001984267
#
# EFT $q q \to t \bar{t}$  mPsiT: 3000.0, mSDM: 2850.0 Result: APROVED
# No bias: xsec = 0.001841360 sum of weights = 0.001841360 bias: xsec = 0.001830550 sum of weights = 0.001830550
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 3000.0, mSDM: 2850.0 Result: APROVED
# No bias: xsec = 0.002006076 sum of weights = 0.002006076 bias: xsec = 0.002011000 sum of weights = 0.002011000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 3000.0, mSDM: 2850.0 Result: APROVED
# No bias: xsec = 0.001857569 sum of weights = 0.001857569 bias: xsec = 0.001860000 sum of weights = 0.001860000
#
# EFT $g g \to t \bar{t}$  mPsiT: 4000.0, mSDM: 3800.0 Result: APROVED
# No bias: xsec = 0.001118597 sum of weights = 0.001118597 bias: xsec = 0.001116181 sum of weights = 0.001116181
#
# EFT $q q \to t \bar{t}$  mPsiT: 4000.0, mSDM: 3800.0 Result: APROVED
# No bias: xsec = 0.001035760 sum of weights = 0.001035760 bias: xsec = 0.001029673 sum of weights = 0.001029673
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 4000.0, mSDM: 3800.0 Result: APROVED
# No bias: xsec = 0.001117418 sum of weights = 0.001117418 bias: xsec = 0.001134000 sum of weights = 0.001134000
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 4000.0, mSDM: 3800.0 Result: APROVED
# No bias: xsec = 0.001038191 sum of weights = 0.001038191 bias: xsec = 0.001037000 sum of weights = 0.001037000
#
# EFT $g g \to t \bar{t}$  mPsiT: 5000.0, mSDM: 4750.0 Result: APROVED
# No bias: xsec = 0.000715898 sum of weights = 0.000715898 bias: xsec = 0.000714328 sum of weights = 0.000714328
#
# EFT $q q \to t \bar{t}$  mPsiT: 5000.0, mSDM: 4750.0 Result: APROVED
# No bias: xsec = 0.000662890 sum of weights = 0.000662890 bias: xsec = 0.000659004 sum of weights = 0.000659004
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 5000.0, mSDM: 4750.0 Result: APROVED
# No bias: xsec = 0.000726142 sum of weights = 0.000726142 bias: xsec = 0.000709200 sum of weights = 0.000709200
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 5000.0, mSDM: 4750.0 Result: APROVED
# No bias: xsec = 0.000663955 sum of weights = 0.000663955 bias: xsec = 0.000662800 sum of weights = 0.000662800
#
# EFT $g g \to t \bar{t}$  mPsiT: 6000.0, mSDM: 5700.0 Result: APROVED
# No bias: xsec = 0.000497153 sum of weights = 0.000497153 bias: xsec = 0.000496061 sum of weights = 0.000496061
#
# EFT $q q \to t \bar{t}$  mPsiT: 6000.0, mSDM: 5700.0 Result: APROVED
# No bias: xsec = 0.000460350 sum of weights = 0.000460350 bias: xsec = 0.000457636 sum of weights = 0.000457636
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 6000.0, mSDM: 5700.0 Result: APROVED
# No bias: xsec = 0.000502891 sum of weights = 0.000502891 bias: xsec = 0.000494200 sum of weights = 0.000494200
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 6000.0, mSDM: 5700.0 Result: APROVED
# No bias: xsec = 0.000460698 sum of weights = 0.000460698 bias: xsec = 0.000458500 sum of weights = 0.000458500
#
# EFT $g g \to t \bar{t}$  mPsiT: 7000.0, mSDM: 6650.0 Result: APROVED
# No bias: xsec = 0.000365250 sum of weights = 0.000365250 bias: xsec = 0.000364444 sum of weights = 0.000364444
#
# EFT $q q \to t \bar{t}$  mPsiT: 7000.0, mSDM: 6650.0 Result: APROVED
# No bias: xsec = 0.000338210 sum of weights = 0.000338210 bias: xsec = 0.000336217 sum of weights = 0.000336217
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 7000.0, mSDM: 6650.0 Result: APROVED
# No bias: xsec = 0.000368098 sum of weights = 0.000368098 bias: xsec = 0.000362800 sum of weights = 0.000362800
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 7000.0, mSDM: 6650.0 Result: APROVED
# No bias: xsec = 0.000338677 sum of weights = 0.000338677 bias: xsec = 0.000334600 sum of weights = 0.000334600
#
# EFT $g g \to t \bar{t}$  mPsiT: 8000.0, mSDM: 7600.0 Result: APROVED
# No bias: xsec = 0.000279644 sum of weights = 0.000279644 bias: xsec = 0.000279036 sum of weights = 0.000279036
#
# EFT $q q \to t \bar{t}$  mPsiT: 8000.0, mSDM: 7600.0 Result: APROVED
# No bias: xsec = 0.000258941 sum of weights = 0.000258941 bias: xsec = 0.000257423 sum of weights = 0.000257423
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 8000.0, mSDM: 7600.0 Result: APROVED
# No bias: xsec = 0.000281618 sum of weights = 0.000281618 bias: xsec = 0.000283100 sum of weights = 0.000283100
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 8000.0, mSDM: 7600.0 Result: APROVED
# No bias: xsec = 0.000259326 sum of weights = 0.000259326 bias: xsec = 0.000252600 sum of weights = 0.000252600
#
# EFT $g g \to t \bar{t}$  mPsiT: 9000.0, mSDM: 8550.0 Result: APROVED
# No bias: xsec = 0.000220957 sum of weights = 0.000220957 bias: xsec = 0.000220465 sum of weights = 0.000220465
#
# EFT $q q \to t \bar{t}$  mPsiT: 9000.0, mSDM: 8550.0 Result: APROVED
# No bias: xsec = 0.000204596 sum of weights = 0.000204596 bias: xsec = 0.000203394 sum of weights = 0.000203394
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 9000.0, mSDM: 8550.0 Result: APROVED
# No bias: xsec = 0.000221051 sum of weights = 0.000221051 bias: xsec = 0.000220400 sum of weights = 0.000220400
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 9000.0, mSDM: 8550.0 Result: APROVED
# No bias: xsec = 0.000204850 sum of weights = 0.000204850 bias: xsec = 0.000206800 sum of weights = 0.000206800
#
# EFT $g g \to t \bar{t}$  mPsiT: 10000.0, mSDM: 9500.0 Result: APROVED
# No bias: xsec = 0.000178979 sum of weights = 0.000178979 bias: xsec = 0.000178577 sum of weights = 0.000178577
#
# EFT $q q \to t \bar{t}$  mPsiT: 10000.0, mSDM: 9500.0 Result: APROVED
# No bias: xsec = 0.000165723 sum of weights = 0.000165723 bias: xsec = 0.000164747 sum of weights = 0.000164747
#
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 10000.0, mSDM: 9500.0 Result: APROVED
# No bias: xsec = 0.000179899 sum of weights = 0.000179899 bias: xsec = 0.000178900 sum of weights = 0.000178900
#
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 10000.0, mSDM: 9500.0 Result: APROVED
# No bias: xsec = 0.000165904 sum of weights = 0.000165904 bias: xsec = 0.000164600 sum of weights = 0.000164600
