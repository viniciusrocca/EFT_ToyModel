# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import random
from auxPlots import selectColor, xSecTest
from aux import getInfo, getLHEevents, getDistributions


pd.option_context('display.max_columns', -1)

pd.options.mode.chained_assignment = None #Disable copy warnings
# plt.style.use('fivethirtyeight') #Set style
# mpl.rcParams.update({'figure.figsize' : (15,10)})  #Set general plotting options
plt.rcParams['figure.max_open_warning'] = 50
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

plt.rcParams.update({"savefig.dpi" : 300}) #Figure resolution


#Define plotting style:
sns.set() #Set style
sns.set_style('ticks',{'font.family':'Times New Roman', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=1.8)
cm = plt.colormaps['RdYlBu']

# %%
#Reading files
files = list(glob.glob('/home/vinicius/EFT_ToyModel/processFolders/Distributions/*/*/*.npz'))
data = []
data_sm = []
#Loading the distributions
for f in files:
    aux = np.load(f, allow_pickle = True)
    if aux['model'] == 'SM':
        data_sm.append(aux)
    else:
        data.append(aux)

data = sorted(data, key=lambda d: d['mass_params'][0])
print(data_sm[2]['process'])
print(data[4]['deltaPhi'], data[5]['model'])
# Out:
# $p p \to t \bar{t}$
# [3.14159265 3.14159265 3.14159265 ... 3.14159265 3.14159265 3.14159265] EFT

# %%
print(data[0]['mass_params'])
xSecTest(data + data_sm, True)
# Out:
# [200. 190.]
# EFT $g g \to t \bar{t}$  mPsiT: 200.0, mSDM: 190.0 Result: Passed
# xsec = 0.447441000 sum of weights = 0.447441000
# EFT $q q \to t \bar{t}$  mPsiT: 200.0, mSDM: 190.0 Result: Passed
# xsec = 0.414310000 sum of weights = 0.414310000
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 200.0, mSDM: 190.0 Result: Passed
# xsec = 0.957268227 sum of weights = 0.957268227
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 200.0, mSDM: 190.0 Result: Passed
# xsec = 0.441245229 sum of weights = 0.441245229
# EFT $g g \to t \bar{t}$  mPsiT: 300.0, mSDM: 285.0 Result: Passed
# xsec = 0.198857600 sum of weights = 0.198857600
# EFT $q q \to t \bar{t}$  mPsiT: 300.0, mSDM: 285.0 Result: Passed
# xsec = 0.184136000 sum of weights = 0.184136000
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 300.0, mSDM: 285.0 Result: Passed
# xsec = 0.409322124 sum of weights = 0.409322124
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 300.0, mSDM: 285.0 Result: Passed
# xsec = 0.249462897 sum of weights = 0.249462897
# EFT $g g \to t \bar{t}$  mPsiT: 400.0, mSDM: 380.0 Result: Passed
# xsec = 0.111859700 sum of weights = 0.111859700
# EFT $q q \to t \bar{t}$  mPsiT: 400.0, mSDM: 380.0 Result: Passed
# xsec = 0.103576000 sum of weights = 0.103576000
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 400.0, mSDM: 380.0 Result: Passed
# xsec = 0.178870147 sum of weights = 0.178870147
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 400.0, mSDM: 380.0 Result: Passed
# xsec = 0.134940210 sum of weights = 0.134940210
# EFT $g g \to t \bar{t}$  mPsiT: 500.0, mSDM: 475.0 Result: Passed
# xsec = 0.071589800 sum of weights = 0.071589800
# EFT $q q \to t \bar{t}$  mPsiT: 500.0, mSDM: 475.0 Result: Passed
# xsec = 0.066289000 sum of weights = 0.066289000
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 500.0, mSDM: 475.0 Result: Passed
# xsec = 0.098850282 sum of weights = 0.098850282
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 500.0, mSDM: 475.0 Result: Passed
# xsec = 0.081606587 sum of weights = 0.081606587
# EFT $g g \to t \bar{t}$  mPsiT: 600.0, mSDM: 570.0 Result: Passed
# xsec = 0.049715300 sum of weights = 0.049715300
# EFT $q q \to t \bar{t}$  mPsiT: 600.0, mSDM: 570.0 Result: Passed
# xsec = 0.046035000 sum of weights = 0.046035000
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 600.0, mSDM: 570.0 Result: Passed
# xsec = 0.062288298 sum of weights = 0.062288298
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 600.0, mSDM: 570.0 Result: Passed
# xsec = 0.054321553 sum of weights = 0.054321553
# EFT $g g \to t \bar{t}$  mPsiT: 700.0, mSDM: 665.0 Result: Passed
# xsec = 0.036525000 sum of weights = 0.036525000
# EFT $q q \to t \bar{t}$  mPsiT: 700.0, mSDM: 665.0 Result: Passed
# xsec = 0.033821000 sum of weights = 0.033821000
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 700.0, mSDM: 665.0 Result: Passed
# xsec = 0.042924456 sum of weights = 0.042924456
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 700.0, mSDM: 665.0 Result: Passed
# xsec = 0.038704574 sum of weights = 0.038704574
# EFT $g g \to t \bar{t}$  mPsiT: 800.0, mSDM: 760.0 Result: Passed
# xsec = 0.027964400 sum of weights = 0.027964400
# EFT $q q \to t \bar{t}$  mPsiT: 800.0, mSDM: 760.0 Result: Passed
# xsec = 0.025894100 sum of weights = 0.025894100
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 800.0, mSDM: 760.0 Result: Passed
# xsec = 0.031898900 sum of weights = 0.031898900
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 800.0, mSDM: 760.0 Result: Passed
# xsec = 0.028936035 sum of weights = 0.028936035
# EFT $g g \to t \bar{t}$  mPsiT: 900.0, mSDM: 855.0 Result: Passed
# xsec = 0.022095680 sum of weights = 0.022095680
# EFT $q q \to t \bar{t}$  mPsiT: 900.0, mSDM: 855.0 Result: Passed
# xsec = 0.020459600 sum of weights = 0.020459600
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 900.0, mSDM: 855.0 Result: Passed
# xsec = 0.024399384 sum of weights = 0.024399384
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 900.0, mSDM: 855.0 Result: Passed
# xsec = 0.022331930 sum of weights = 0.022331930
# EFT $g g \to t \bar{t}$  mPsiT: 1000.0, mSDM: 950.0 Result: Passed
# xsec = 0.017897950 sum of weights = 0.017897950
# EFT $q q \to t \bar{t}$  mPsiT: 1000.0, mSDM: 950.0 Result: Passed
# xsec = 0.016572300 sum of weights = 0.016572300
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 1000.0, mSDM: 950.0 Result: Passed
# xsec = 0.019340984 sum of weights = 0.019340984
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 1000.0, mSDM: 950.0 Result: Passed
# xsec = 0.017732242 sum of weights = 0.017732242
# EFT $g g \to t \bar{t}$  mPsiT: 1250.0, mSDM: 1188.0 Result: Passed
# xsec = 0.011453920 sum of weights = 0.011453920
# EFT $q q \to t \bar{t}$  mPsiT: 1250.0, mSDM: 1188.0 Result: Passed
# xsec = 0.010606300 sum of weights = 0.010606300
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 1250.0, mSDM: 1188.0 Result: Passed
# xsec = 0.012009718 sum of weights = 0.012009718
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 1250.0, mSDM: 1188.0 Result: Passed
# xsec = 0.011100994 sum of weights = 0.011100994
# EFT $g g \to t \bar{t}$  mPsiT: 1500.0, mSDM: 1425.0 Result: Passed
# xsec = 0.007954380 sum of weights = 0.007954380
# EFT $q q \to t \bar{t}$  mPsiT: 1500.0, mSDM: 1425.0 Result: Passed
# xsec = 0.007365400 sum of weights = 0.007365400
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 1500.0, mSDM: 1425.0 Result: Passed
# xsec = 0.008237281 sum of weights = 0.008237281
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 1500.0, mSDM: 1425.0 Result: Passed
# xsec = 0.007594877 sum of weights = 0.007594877
# EFT $g g \to t \bar{t}$  mPsiT: 2000.0, mSDM: 1900.0 Result: Passed
# xsec = 0.004474390 sum of weights = 0.004474390
# EFT $q q \to t \bar{t}$  mPsiT: 2000.0, mSDM: 1900.0 Result: Passed
# xsec = 0.004143100 sum of weights = 0.004143100
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 2000.0, mSDM: 1900.0 Result: Passed
# xsec = 0.004566539 sum of weights = 0.004566539
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 2000.0, mSDM: 1900.0 Result: Passed
# xsec = 0.004200238 sum of weights = 0.004200238
# EFT $g g \to t \bar{t}$  mPsiT: 2500.0, mSDM: 2375.0 Result: Passed
# xsec = 0.002863630 sum of weights = 0.002863630
# EFT $q q \to t \bar{t}$  mPsiT: 2500.0, mSDM: 2375.0 Result: Passed
# xsec = 0.002651560 sum of weights = 0.002651560
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 2500.0, mSDM: 2375.0 Result: Passed
# xsec = 0.002904101 sum of weights = 0.002904101
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 2500.0, mSDM: 2375.0 Result: Passed
# xsec = 0.002675403 sum of weights = 0.002675403
# EFT $g g \to t \bar{t}$  mPsiT: 3000.0, mSDM: 2850.0 Result: Passed
# xsec = 0.001988572 sum of weights = 0.001988572
# EFT $q q \to t \bar{t}$  mPsiT: 3000.0, mSDM: 2850.0 Result: Passed
# xsec = 0.001841360 sum of weights = 0.001841360
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 3000.0, mSDM: 2850.0 Result: Passed
# xsec = 0.002006076 sum of weights = 0.002006076
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 3000.0, mSDM: 2850.0 Result: Passed
# xsec = 0.001857569 sum of weights = 0.001857569
# EFT $g g \to t \bar{t}$  mPsiT: 4000.0, mSDM: 3800.0 Result: Passed
# xsec = 0.001118597 sum of weights = 0.001118597
# EFT $q q \to t \bar{t}$  mPsiT: 4000.0, mSDM: 3800.0 Result: Passed
# xsec = 0.001035760 sum of weights = 0.001035760
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 4000.0, mSDM: 3800.0 Result: Passed
# xsec = 0.001117418 sum of weights = 0.001117418
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 4000.0, mSDM: 3800.0 Result: Passed
# xsec = 0.001038191 sum of weights = 0.001038191
# EFT $g g \to t \bar{t}$  mPsiT: 5000.0, mSDM: 4750.0 Result: Passed
# xsec = 0.000715898 sum of weights = 0.000715898
# EFT $q q \to t \bar{t}$  mPsiT: 5000.0, mSDM: 4750.0 Result: Passed
# xsec = 0.000662890 sum of weights = 0.000662890
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 5000.0, mSDM: 4750.0 Result: Passed
# xsec = 0.000726142 sum of weights = 0.000726142
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 5000.0, mSDM: 4750.0 Result: Passed
# xsec = 0.000663955 sum of weights = 0.000663955
# EFT $g g \to t \bar{t}$  mPsiT: 6000.0, mSDM: 5700.0 Result: Passed
# xsec = 0.000497153 sum of weights = 0.000497153
# EFT $q q \to t \bar{t}$  mPsiT: 6000.0, mSDM: 5700.0 Result: Passed
# xsec = 0.000460350 sum of weights = 0.000460350
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 6000.0, mSDM: 5700.0 Result: Passed
# xsec = 0.000502891 sum of weights = 0.000502891
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 6000.0, mSDM: 5700.0 Result: Passed
# xsec = 0.000460698 sum of weights = 0.000460698
# EFT $g g \to t \bar{t}$  mPsiT: 7000.0, mSDM: 6650.0 Result: Passed
# xsec = 0.000365250 sum of weights = 0.000365250
# EFT $q q \to t \bar{t}$  mPsiT: 7000.0, mSDM: 6650.0 Result: Passed
# xsec = 0.000338210 sum of weights = 0.000338210
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 7000.0, mSDM: 6650.0 Result: Passed
# xsec = 0.000368098 sum of weights = 0.000368098
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 7000.0, mSDM: 6650.0 Result: Passed
# xsec = 0.000338677 sum of weights = 0.000338677
# EFT $g g \to t \bar{t}$  mPsiT: 8000.0, mSDM: 7600.0 Result: Passed
# xsec = 0.000279644 sum of weights = 0.000279644
# EFT $q q \to t \bar{t}$  mPsiT: 8000.0, mSDM: 7600.0 Result: Passed
# xsec = 0.000258941 sum of weights = 0.000258941
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 8000.0, mSDM: 7600.0 Result: Passed
# xsec = 0.000281618 sum of weights = 0.000281618
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 8000.0, mSDM: 7600.0 Result: Passed
# xsec = 0.000259326 sum of weights = 0.000259326
# EFT $g g \to t \bar{t}$  mPsiT: 9000.0, mSDM: 8550.0 Result: Passed
# xsec = 0.000220957 sum of weights = 0.000220957
# EFT $q q \to t \bar{t}$  mPsiT: 9000.0, mSDM: 8550.0 Result: Passed
# xsec = 0.000204596 sum of weights = 0.000204596
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 9000.0, mSDM: 8550.0 Result: Passed
# xsec = 0.000221051 sum of weights = 0.000221051
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 9000.0, mSDM: 8550.0 Result: Passed
# xsec = 0.000204850 sum of weights = 0.000204850
# EFT $g g \to t \bar{t}$  mPsiT: 10000.0, mSDM: 9500.0 Result: Passed
# xsec = 0.000178979 sum of weights = 0.000178979
# EFT $q q \to t \bar{t}$  mPsiT: 10000.0, mSDM: 9500.0 Result: Passed
# xsec = 0.000165723 sum of weights = 0.000165723
# 1-loop UV $g g \to t \bar{t}$  mPsiT: 10000.0, mSDM: 9500.0 Result: Passed
# xsec = 0.000179899 sum of weights = 0.000179899
# 1-loop UV $q q \to t \bar{t}$  mPsiT: 10000.0, mSDM: 9500.0 Result: Passed
# xsec = 0.000165904 sum of weights = 0.000165904
# SM $q q \to t \bar{t}$  mPsiT: 0.0, mSDM: 0.0 Result: Passed
# xsec = 63.041000000 sum of weights = 63.041000000
# SM $g g \to t \bar{t}$  mPsiT: 0.0, mSDM: 0.0 Result: Passed
# xsec = 404.331000000 sum of weights = 404.330999999
# SM $p p \to t \bar{t}$  mPsiT: 0.0, mSDM: 0.0 Result: Passed
# xsec = 467.308000000 sum of weights = 467.307999999

# %%
 for d in data:
    print(d['mass_params'][0], d['model'], d['process'], d['nevents'])
# Out:
# 200.0 EFT $g g \to t \bar{t}$ 75000
# 200.0 EFT $q q \to t \bar{t}$ 75000
# 200.0 1-loop UV $g g \to t \bar{t}$ 51491
# 200.0 1-loop UV $q q \to t \bar{t}$ 103770
# 300.0 EFT $g g \to t \bar{t}$ 75000
# 300.0 EFT $q q \to t \bar{t}$ 75000
# 300.0 1-loop UV $g g \to t \bar{t}$ 51426
# 300.0 1-loop UV $q q \to t \bar{t}$ 103602
# 400.0 EFT $g g \to t \bar{t}$ 75000
# 400.0 EFT $q q \to t \bar{t}$ 75000
# 400.0 1-loop UV $g g \to t \bar{t}$ 51417
# 400.0 1-loop UV $q q \to t \bar{t}$ 103530
# 500.0 EFT $g g \to t \bar{t}$ 75000
# 500.0 EFT $q q \to t \bar{t}$ 75000
# 500.0 1-loop UV $g g \to t \bar{t}$ 51428
# 500.0 1-loop UV $q q \to t \bar{t}$ 103356
# 600.0 EFT $g g \to t \bar{t}$ 75000
# 600.0 EFT $q q \to t \bar{t}$ 75000
# 600.0 1-loop UV $g g \to t \bar{t}$ 51459
# 600.0 1-loop UV $q q \to t \bar{t}$ 103380
# 700.0 EFT $g g \to t \bar{t}$ 75000
# 700.0 EFT $q q \to t \bar{t}$ 75000
# 700.0 1-loop UV $g g \to t \bar{t}$ 51456
# 700.0 1-loop UV $q q \to t \bar{t}$ 103243
# 800.0 EFT $g g \to t \bar{t}$ 75000
# 800.0 EFT $q q \to t \bar{t}$ 75000
# 800.0 1-loop UV $g g \to t \bar{t}$ 51458
# 800.0 1-loop UV $q q \to t \bar{t}$ 103219
# 900.0 EFT $g g \to t \bar{t}$ 75000
# 900.0 EFT $q q \to t \bar{t}$ 75000
# 900.0 1-loop UV $g g \to t \bar{t}$ 51519
# 900.0 1-loop UV $q q \to t \bar{t}$ 103268
# 1000.0 EFT $g g \to t \bar{t}$ 75000
# 1000.0 EFT $q q \to t \bar{t}$ 75000
# 1000.0 1-loop UV $g g \to t \bar{t}$ 51507
# 1000.0 1-loop UV $q q \to t \bar{t}$ 103265
# 1250.0 EFT $g g \to t \bar{t}$ 75000
# 1250.0 EFT $q q \to t \bar{t}$ 75000
# 1250.0 1-loop UV $g g \to t \bar{t}$ 51482
# 1250.0 1-loop UV $q q \to t \bar{t}$ 103434
# 1500.0 EFT $g g \to t \bar{t}$ 75000
# 1500.0 EFT $q q \to t \bar{t}$ 75000
# 1500.0 1-loop UV $g g \to t \bar{t}$ 51480
# 1500.0 1-loop UV $q q \to t \bar{t}$ 103528
# 2000.0 EFT $g g \to t \bar{t}$ 75000
# 2000.0 EFT $q q \to t \bar{t}$ 75000
# 2000.0 1-loop UV $g g \to t \bar{t}$ 51526
# 2000.0 1-loop UV $q q \to t \bar{t}$ 103456
# 2500.0 EFT $g g \to t \bar{t}$ 75000
# 2500.0 EFT $q q \to t \bar{t}$ 75000
# 2500.0 1-loop UV $g g \to t \bar{t}$ 51528
# 2500.0 1-loop UV $q q \to t \bar{t}$ 103462
# 3000.0 EFT $g g \to t \bar{t}$ 75000
# 3000.0 EFT $q q \to t \bar{t}$ 75000
# 3000.0 1-loop UV $g g \to t \bar{t}$ 51512
# 3000.0 1-loop UV $q q \to t \bar{t}$ 103463
# 4000.0 EFT $g g \to t \bar{t}$ 75000
# 4000.0 EFT $q q \to t \bar{t}$ 75000
# 4000.0 1-loop UV $g g \to t \bar{t}$ 51549
# 4000.0 1-loop UV $q q \to t \bar{t}$ 103473
# 5000.0 EFT $g g \to t \bar{t}$ 75000
# 5000.0 EFT $q q \to t \bar{t}$ 75000
# 5000.0 1-loop UV $g g \to t \bar{t}$ 51459
# 5000.0 1-loop UV $q q \to t \bar{t}$ 103464
# 6000.0 EFT $g g \to t \bar{t}$ 75000
# 6000.0 EFT $q q \to t \bar{t}$ 75000
# 6000.0 1-loop UV $g g \to t \bar{t}$ 51471
# 6000.0 1-loop UV $q q \to t \bar{t}$ 103461
# 7000.0 EFT $g g \to t \bar{t}$ 75000
# 7000.0 EFT $q q \to t \bar{t}$ 75000
# 7000.0 1-loop UV $g g \to t \bar{t}$ 51473
# 7000.0 1-loop UV $q q \to t \bar{t}$ 103417
# 8000.0 EFT $g g \to t \bar{t}$ 75000
# 8000.0 EFT $q q \to t \bar{t}$ 75000
# 8000.0 1-loop UV $g g \to t \bar{t}$ 51419
# 8000.0 1-loop UV $q q \to t \bar{t}$ 103469
# 9000.0 EFT $g g \to t \bar{t}$ 75000
# 9000.0 EFT $q q \to t \bar{t}$ 75000
# 9000.0 1-loop UV $g g \to t \bar{t}$ 51453
# 9000.0 1-loop UV $q q \to t \bar{t}$ 103469
# 10000.0 EFT $g g \to t \bar{t}$ 75000
# 10000.0 EFT $q q \to t \bar{t}$ 75000
# 10000.0 1-loop UV $g g \to t \bar{t}$ 51460
# 10000.0 1-loop UV $q q \to t \bar{t}$ 103469

# %% [markdown]
# # Invariant mass $qq\to t\bar{t}$

# %%
# Generating the BSM histograms and plotting them
# Coupling value
yDM = 1.0

#Loop over the masses configurations. Each mass configuration has 2 models with 2 processes each
for i in range(0, len(data), 4):
    #Selecting the models and process for the same mass configuration
    selected = data[i : i+4]

    #Defining the space for the two plots 
    _, axarr = plt.subplots(2,sharex=True, gridspec_kw = {'height_ratios':[2, 1]},figsize=(8,8))
    plt.subplots_adjust(left=0.12, bottom=0.12, right=0.97, top=None, wspace=None, hspace=0.1)

    #Variables used to store hist info
    #BSM masses
    mPsiT,mSDM = selected[0]['mass_params']
    #Defining the binning according to the BSM masses
    if mPsiT < 800.0:
        bins = np.arange(400.,1550.,35.)
    elif mPsiT <= 1250:
        bins = np.arange(500.,2000.,45.)
    else:
        bins = np.arange(700.,3300.,75.)
    #Loop over the processes and models

    #SM plot
    labels_sm = []
    pmodels = []
    hists_sm = []
    histsErr_sm = []
    hists_sm_norm = []

    for d in data_sm:
        process = d['process']
        model = d['model']
        weights = d['weights']
        pmodels.append(r'%s (%s)' %(process,model))
        label = pmodels[-1]
        labels_sm.append(label)
        h,_ = np.histogram(d['mTT'],bins=bins,weights=d['weights'])
        hists_sm.append(h)
        #Compute MC error
        hErr,_ = np.histogram(d['mTT'],bins=bins,weights=(d['weights'])**2)
        hErr = np.sqrt(hErr)    
        histsErr_sm.append(hErr)
    #Plotting the SM hist
    aux = axarr[0].hist(bins[:-1],weights=np.abs(hists_sm[2]),label=labels_sm[2],bins=bins,
                          color=sns.color_palette('Paired')[9],alpha=0.3,histtype='step',density=True,
                         linewidth=0,fill=True,stacked=True,linestyle='solid')
    #Storing the normalized histogram
    hists_sm_norm.append(aux[0])

    #Plotting the SM error
    x = (bins[:-1]+bins[1:])/2.0
    y = aux[0]
    #We have to propagate the error because we are using density = True
    yErr = abs(y)*np.sqrt((np.array(histsErr_sm[2])/np.array(hists_sm[2]))**2 + sum(np.power(histsErr_sm[2],2))/(sum(hists_sm[2])**2))  
    #Plot
    axarr[0].errorbar(x,y, yerr = yErr,
                    color=sns.color_palette('Paired')[9], fmt = 'none', ms = 5, capsize = 3.5, capthick = 1.2, 
                      ecolor =sns.color_palette('Paired')[9], barsabove = True, alpha = 0.3)
    
    #variables to store info
    labels = []
    pmodels = []
    hists = []
    histsErr = []
    hErr_norm = []
    c = []
    hists_norm = []
    
    for j,d in enumerate(selected):
        if r'$g g \to t \bar{t}$' in d['process']:
            labels.append('0')
            c.append('0')
            continue
        else:
            process = d['process']
            model = d['model']
            weights = d['weights']
            pmodels.append(r'%s (%s)' %(process,model))
            #Cs and weights test
            #if model == '1-loop UV':
             #   print('UV:', d['nevents']*sum(d['weights']), d['xsec (pb)'])
            #else:
             #   print('EFT:', sum(d['weights']), d['xsec (pb)'])
            label = pmodels[-1]
            labels.append(label)
            c.append(selectColor(model,process))
            h,_ = np.histogram(d['mTT'],bins=bins,weights=d['weights'])
            hists.append(h)
            #Compute MC error
            hErr,_ = np.histogram(d['mTT'],bins=bins,weights=(d['weights'])**2)
            hErr = np.sqrt(hErr)    
            histsErr.append(hErr)
            #Plotting the BSM hists
            aux = axarr[0].hist(bins[:-1],weights=abs(h),label=labels[j],bins=bins,
                              color=c[j],alpha=1.0,histtype='step',
                             linewidth=2,fill=False,zorder=i,linestyle='solid')
            hists_norm.append(aux[0])
            
            #Plotting the errors
            x = (bins[:-1]+bins[1:])/2.0
            y = aux[0]
            #Propagating the error since we are dealing with normalized histograms
            yErr = abs(y)*np.sqrt((np.array(hErr)/np.array(h))**2 + sum(np.power(hErr,2))/(sum(h)**2))
            hErr_norm.append(yErr)
            axarr[0].errorbar(x,aux[0], yerr = yErr,
                          color=c[j], fmt = 'none', capsize = 3, capthick = 1.2, barsabove = True)
           
        
    

    #Ratio plot
    # Separating the EFT and the 1-loop UV results
    hLoop = hists[1]
    hLoop_Err = histsErr[1]
    hEFT = hists[0]
    hEFT_Err = histsErr[0]
    #Computing the ratio EFT/1-loop UV
    labels_r = [r'$q q \to t \bar{t}$']
    ratio = np.divide(hEFT , hLoop, out=np.zeros_like(hLoop),where=hLoop != 0)
    ratio_Err = abs(ratio)*np.sqrt((np.array(hEFT_Err)/np.array(hEFT))**2 + (np.array(hLoop_Err)/np.array(hLoop))**2)
    # Remove zero values
    nonzero = np.where((np.sign(ratio) != 0))
    x = (bins[:-1]+bins[1:])/2.0
    y = ratio
    label = labels_r[0]
        #Ratio plots
    axarr[1].plot(x,y,linewidth=1.5,linestyle='solid',alpha=1,
                              label=label,c=c[j])
    axarr[1].errorbar(x,y, yerr = ratio_Err,
                          color=c[j], fmt = 'o', ms = 0, capsize = 3.5, capthick = 1.2 )
        
    #Main plot configs
    axarr[0].legend(framealpha=1.0,loc='upper right',fontsize=15)
    axarr[0].set_title(r'$m_{\psi_T} = %1.0f$ GeV, $m_{s} = %1.0f$ GeV, $y_{DM} = $%1.1f' %(mPsiT,mSDM,yDM),
                   loc='left')
    axarr[0].set_yscale('log')
    axarr[0].set_ylabel(r'$|\frac{1}{\sigma}\frac{d \sigma}{d m(t\bar{t})}|$')
    axarr[0].set_xlim(bins.min(),bins.max())
    axarr[1].set_ylabel(r'$N_{EFT}/N_{1-loop}$')
    
    #Subplot configs
    axarr[1].set_ylim(-1,1.5)
    #axarr[1].set_yticks(np.arange(-0.01,0.05,0.01))
    #axarr[1].set_yscale('log')
    axarr[1].grid()
    axarr[1].axhline(y=1, color='k', linestyle='--')
    axarr[1].legend(loc='lower left',fontsize=12,framealpha=1.0,ncol=2)
    axarr[1].set_xlabel(r'$m(t\bar{t})$ (GeV)')
    
plt.show()
# Out:
# /tmp/ipykernel_16954/2790297423.py:57: RuntimeWarning: invalid value encountered in divide
#   yErr = abs(y)*np.sqrt((np.array(histsErr_sm[2])/np.array(hists_sm[2]))**2 + sum(np.power(histsErr_sm[2],2))/(sum(hists_sm[2])**2))

# %% [markdown]
# # $p_T$ $qq\to t\bar{t}$

# %%
#Generating the BSM histograms and plotting them
bins = np.arange(500.,2000.,75.)
# Coupling value
yDM = 1.0

#Loop over the masses configurations. Each mass configuration has 2 models with 2 processes each
for i in range(0, len(data), 4):
    #Selecting the models and process for the same mass configuration
    selected = data[i : i+4]

    #Defining the space for the two plots 
    _, axarr = plt.subplots(2,sharex=True, gridspec_kw = {'height_ratios':[2, 1]},figsize=(8,8))
    plt.subplots_adjust(left=0.12, bottom=0.12, right=0.97, top=None, wspace=None, hspace=0.1)

    mPsiT,mSDM = selected[0]['mass_params']
     #Defining the binning according to the BSM masses
    if mPsiT < 1250.:
        bins = np.arange(100.,1550.,50.)
    else:
        bins = np.arange(500.,2000.,75.)
        
    #SM plot
    labels_sm = []
    pmodels = []
    hists_sm = []
    histsErr_sm = []
    hists_sm_norm = []

    for d in data_sm:
        process = d['process']
        model = d['model']
        weights = d['weights']
        pmodels.append(r'%s (%s)' %(process,model))
        label = pmodels[-1]
        labels_sm.append(label)
        h,_ = np.histogram(d['pT'],bins=bins,weights=d['weights'])
        hists_sm.append(h)
        #Compute MC error
        hErr,_ = np.histogram(d['pT'],bins=bins,weights=(d['weights'])**2)
        hErr = np.sqrt(hErr)    
        histsErr_sm.append(hErr)
    #Plotting the SM hist
    aux = axarr[0].hist(bins[:-1],weights=np.abs(hists_sm[2]),label=labels_sm[2],bins=bins,
                          color=sns.color_palette('Paired')[9],alpha=0.3,histtype='step',density=True,
                         linewidth=0,fill=True,stacked=True,linestyle='solid')
    #Storing the normalized histogram
    hists_sm_norm.append(aux[0])

    #Plotting the SM error
    x = (bins[:-1]+bins[1:])/2.0
    y = aux[0]
    #We have to propagate the error because we are using density = True
    yErr = abs(y)*np.sqrt((np.array(histsErr_sm[2])/np.array(hists_sm[2]))**2 + sum(np.power(histsErr_sm[2],2))/(sum(hists_sm[2])**2))  
    #Plot
    axarr[0].errorbar(x,y, yerr = yErr,
                    color=sns.color_palette('Paired')[9], fmt = 'none', ms = 5, capsize = 3.5, capthick = 1.2, 
                      ecolor =sns.color_palette('Paired')[9], barsabove = True, alpha = 0.3)
    
    #variables to store info
    labels = []
    pmodels = []
    hists = []
    histsErr = []
    hErr_norm = []
    c = []
    hists_norm = []
    
    for j,d in enumerate(selected):
        if r'$g g \to t \bar{t}$' in d['process']:
            labels.append('0')
            c.append('0')
            continue
        else:
            process = d['process']
            model = d['model']
            weights = d['weights']
            pmodels.append(r'%s (%s)' %(process,model))
            label = pmodels[-1]
            labels.append(label)
            c.append(selectColor(model,process))
            h,_ = np.histogram(d['pT'],bins=bins,weights=d['weights'])
            hists.append(h)
            #Compute MC error
            hErr,_ = np.histogram(d['pT'],bins=bins,weights=(d['weights'])**2)
            hErr = np.sqrt(hErr)    
            histsErr.append(hErr)
            #Plotting the BSM hists
            aux = axarr[0].hist(bins[:-1],weights=abs(h),label=labels[j],bins=bins,
                              color=c[j],alpha=1.0,histtype='step',density=True,
                             linewidth=2,fill=False,zorder=i,linestyle='solid')
            hists_norm.append(aux[0])
            
            #Plotting the errors
            x = (bins[:-1]+bins[1:])/2.0
            y = aux[0]
            #Propagating the error since we are dealing with normalized histograms
            yErr = abs(y)*np.sqrt((np.array(hErr)/np.array(h))**2 + sum(np.power(hErr,2))/(sum(h)**2))
            hErr_norm.append(yErr)
            axarr[0].errorbar(x,aux[0], yerr = yErr,
                          color=c[j], fmt = 'none', capsize = 3, capthick = 1.2, barsabove = True)
           
        
    

    #Ratio plot
    # Separating the EFT and the 1-loop UV results
    hLoop = hists[1]
    hLoop_Err = histsErr[1]
    hEFT = hists[0]
    hEFT_Err = histsErr[0]
    #Computing the ratio EFT/1-loop UV
    labels_r = [r'$q q \to t \bar{t}$']
    ratio = np.divide(hEFT , hLoop, out=np.zeros_like(hLoop),where=hLoop != 0)
    ratio_Err = abs(ratio)*np.sqrt((np.array(hEFT_Err)/np.array(hEFT))**2 + (np.array(hLoop_Err)/np.array(hLoop))**2)
    # Remove zero values
    nonzero = np.where((np.sign(ratio) != 0))
    x = (bins[:-1]+bins[1:])/2.0
    y = ratio
    label = labels_r[0]
        #Ratio plots
    axarr[1].plot(x,y,linewidth=1.5,linestyle='solid',alpha=1,
                              label=label,c=c[j])
    axarr[1].errorbar(x,y, yerr = ratio_Err,
                          color=c[j], fmt = 'o', ms = 0, capsize = 3.5, capthick = 1.2 )
        
    #Main plot configs
    axarr[0].legend(framealpha=1.0,loc='upper right',fontsize=15)
    axarr[0].set_title(r'$m_{\psi_T} = %1.0f$ GeV, $m_{s} = %1.0f$ GeV, $y_{DM} = $%1.1f' %(mPsiT,mSDM,yDM),
                   loc='left')
    axarr[0].set_yscale('log')
    axarr[0].set_ylabel(r'$|\frac{1}{\sigma}\frac{d \sigma}{d p_T(t)}|$')
    axarr[0].set_xlim(bins.min(),bins.max())
    axarr[1].set_ylabel(r'$N_{EFT}/N_{1-loop}$')
    
    #Subplot configs
    axarr[1].set_ylim(-1,1.5)
    #axarr[1].set_yticks(np.arange(-0.01,0.05,0.01))
    #axarr[1].set_yscale('log')
    axarr[1].grid()
    axarr[1].axhline(y=1, color='k', linestyle='--')
    axarr[1].legend(loc='lower left',fontsize=12,framealpha=1.0,ncol=2)
    axarr[1].set_xlabel(r'$p_T(t)$ (GeV)')
    
plt.show()
# Out:
# /tmp/ipykernel_16954/4154594043.py:53: RuntimeWarning: invalid value encountered in divide
#   yErr = abs(y)*np.sqrt((np.array(histsErr_sm[2])/np.array(hists_sm[2]))**2 + sum(np.power(histsErr_sm[2],2))/(sum(hists_sm[2])**2))
# /tmp/ipykernel_16954/4154594043.py:97: RuntimeWarning: invalid value encountered in divide
#   yErr = abs(y)*np.sqrt((np.array(hErr)/np.array(h))**2 + sum(np.power(hErr,2))/(sum(h)**2))
# /tmp/ipykernel_16954/4154594043.py:114: RuntimeWarning: invalid value encountered in divide
#   ratio_Err = abs(ratio)*np.sqrt((np.array(hEFT_Err)/np.array(hEFT))**2 + (np.array(hLoop_Err)/np.array(hLoop))**2)

# %% [markdown]
# # $\Delta\varphi$ $qq\to t\bar{t}$

# %%
#type of the distribution

dist = 'deltaPhi'
# Coupling value
yDM = 1.0

#Loop over the masses configurations. Each mass configuration has 2 models with 2 processes each
for i in range(0, len(data), 4):
    #Selecting the models and process for the same mass configuration
    selected = data[i : i+4]

    #Defining the space for the two plots 
    _, axarr = plt.subplots(2,sharex=True, gridspec_kw = {'height_ratios':[2, 1]},figsize=(8,8))
    plt.subplots_adjust(left=0.12, bottom=0.12, right=0.97, top=None, wspace=None, hspace=0.1)

    #Variables used to store hist info
    #BSM masses
    mPsiT,mSDM = selected[0]['mass_params']
    #Defining the binning according to the BSM masses
    bins = np.arange(-np.pi-0.1,np.pi+0.2,0.1)

    #SM plot
    labels_sm = []
    pmodels = []
    hists_sm = []
    histsErr_sm = []
    hists_sm_norm = []

    for d in data_sm:
        process = d['process']
        model = d['model']
        weights = d['weights']
        pmodels.append(r'%s (%s)' %(process,model))
        label = pmodels[-1]
        labels_sm.append(label)
        h,_ = np.histogram(d[dist],bins=bins,weights=d['weights'])
        hists_sm.append(h)
        #Compute MC error
        hErr,_ = np.histogram(d[dist],bins=bins,weights=(d['weights'])**2)
        hErr = np.sqrt(hErr)    
        histsErr_sm.append(hErr)
    #Plotting the SM hist
    aux = axarr[0].hist(bins[:-1],weights=np.abs(hists_sm[2]),label=labels_sm[2],bins=bins,
                          color=sns.color_palette('Paired')[9],alpha=0.3,histtype='step',density=True,
                         linewidth=0,fill=True,stacked=True,linestyle='solid')
    #Storing the normalized histogram
    hists_sm_norm.append(aux[0])

    #Plotting the SM error
    x = (bins[:-1]+bins[1:])/2.0
    y = aux[0]
    #We have to propagate the error because we are using density = True
    yErr = abs(y)*np.sqrt((np.array(histsErr_sm[2])/np.array(hists_sm[2]))**2 + sum(np.power(histsErr_sm[2],2))/(sum(hists_sm[2])**2))  
    #Plot
    axarr[0].errorbar(x,y, yerr = yErr,
                    color=sns.color_palette('Paired')[9], fmt = 'none', ms = 5, capsize = 3.5, capthick = 1.2, 
                      ecolor =sns.color_palette('Paired')[9], barsabove = True, alpha = 0.3)
    
    #variables to store info
    labels = []
    pmodels = []
    hists = []
    histsErr = []
    hErr_norm = []
    c = []
    hists_norm = []
    
    for j,d in enumerate(selected):
        if r'$g g \to t \bar{t}$' in d['process']:
            labels.append('0')
            c.append('0')
            continue
        else:
            process = d['process']
            model = d['model']
            weights = d['weights']
            pmodels.append(r'%s (%s)' %(process,model))
            #Cs and weights test
            #if model == '1-loop UV':
             #   print('UV:', d['nevents']*sum(d['weights']), d['xsec (pb)'])
            #else:
             #   print('EFT:', sum(d['weights']), d['xsec (pb)'])
            label = pmodels[-1]
            labels.append(label)
            c.append(selectColor(model,process))
            h,_ = np.histogram(d[dist],bins=bins,weights=d['weights'])
            hists.append(h)
            #Compute MC error
            hErr,_ = np.histogram(d[dist],bins=bins,weights=(d['weights'])**2)
            hErr = np.sqrt(hErr)    
            histsErr.append(hErr)
            #Plotting the BSM hists
            aux = axarr[0].hist(bins[:-1],weights=abs(h),label=labels[j],bins=bins,
                              color=c[j],alpha=1.0,histtype='step', density = True,
                             linewidth=2,fill=False,zorder=i,linestyle='solid')
            hists_norm.append(aux[0])
            
            #Plotting the errors
            x = (bins[:-1]+bins[1:])/2.0
            y = aux[0]
            #Propagating the error since we are dealing with normalized histograms
            yErr = abs(y)*np.sqrt((np.array(hErr)/np.array(h))**2 + sum(np.power(hErr,2))/(sum(h)**2))
            hErr_norm.append(yErr)
            axarr[0].errorbar(x,aux[0], yerr = yErr,
                          color=c[j], fmt = 'none', capsize = 3, capthick = 1.2, barsabove = True)
           
        
    

    #Ratio plot
    # Separating the EFT and the 1-loop UV results
    hLoop = hists[1]
    hLoop_Err = histsErr[1]
    hEFT = hists[0]
    hEFT_Err = histsErr[0]
    #Computing the ratio EFT/1-loop UV
    labels_r = [r'$q q \to t \bar{t}$']
    ratio = np.divide(hEFT , hLoop, out=np.zeros_like(hLoop),where=hLoop != 0)
    ratio_Err = abs(ratio)*np.sqrt((np.array(hEFT_Err)/np.array(hEFT))**2 + (np.array(hLoop_Err)/np.array(hLoop))**2)
    # Remove zero values
    nonzero = np.where((np.sign(ratio) != 0))
    x = (bins[:-1]+bins[1:])/2.0
    y = ratio
    label = labels_r[0]
        #Ratio plots
    axarr[1].plot(x,y,linewidth=1.5,linestyle='solid',alpha=1,
                              label=label,c=c[j])
    axarr[1].errorbar(x,y, yerr = ratio_Err,
                          color=c[j], fmt = 'o', ms = 0, capsize = 3.5, capthick = 1.2 )
        
    #Main plot configs
    axarr[0].legend(framealpha=1.0,loc='upper right',fontsize=15)
    axarr[0].set_title(r'$m_{\psi_T} = %1.0f$ GeV, $m_{s} = %1.0f$ GeV, $y_{DM} = $%1.1f' %(mPsiT,mSDM,yDM),
                   loc='left')
    #axarr[0].set_yscale('log')
    axarr[0].set_ylabel(r'$|\frac{1}{\sigma}\frac{d \sigma}{d m(t\bar{t})}|$')
    axarr[0].set_xlim(bins.min(),bins.max())
    axarr[1].set_ylabel(r'$N_{EFT}/N_{1-loop}$')
    
    #Subplot configs
    axarr[1].set_ylim(-1,1.5)
    #axarr[1].set_yticks(np.arange(-0.01,0.05,0.01))
    #axarr[1].set_yscale('log')
    axarr[1].grid()
    axarr[1].axhline(y=1, color='k', linestyle='--')
    axarr[1].legend(loc='lower left',fontsize=12,framealpha=1.0,ncol=2)
    axarr[1].set_xlabel(r'$m(t\bar{t})$ (GeV)')
    
plt.show()
# Out:
# /tmp/ipykernel_16954/291128136.py:53: RuntimeWarning: invalid value encountered in divide
#   yErr = abs(y)*np.sqrt((np.array(histsErr_sm[2])/np.array(hists_sm[2]))**2 + sum(np.power(histsErr_sm[2],2))/(sum(hists_sm[2])**2))
# /tmp/ipykernel_16954/291128136.py:102: RuntimeWarning: invalid value encountered in divide
#   yErr = abs(y)*np.sqrt((np.array(hErr)/np.array(h))**2 + sum(np.power(hErr,2))/(sum(h)**2))
# /tmp/ipykernel_16954/291128136.py:119: RuntimeWarning: invalid value encountered in divide
#   ratio_Err = abs(ratio)*np.sqrt((np.array(hEFT_Err)/np.array(hEFT))**2 + (np.array(hLoop_Err)/np.array(hLoop))**2)
