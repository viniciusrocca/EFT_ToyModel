# %% [markdown]
# # Plot scan

# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from scipy.interpolate import LinearNDInterpolator
from scipy.interpolate import interp1d
sys.path.append('../')
from auxPlots import interpolateData,getContours,saveContours
pd.option_context('display.max_columns', -1)

pd.options.mode.chained_assignment = None #Disable copy warnings
# plt.style.use('fivethirtyeight') #Set style
# mpl.rcParams.update({'figure.figsize' : (15,10)})  #Set general plotting options
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

plt.rcParams.update({"savefig.dpi" : 300}) #Figure resolution


#Define plotting style:
sns.set() #Set style
sns.set_style('ticks',{'font.family':'Times New Roman', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=1.8)
cm = plt.colormaps['RdYlBu']

# %% [markdown]
# #### Create txname/process translator

# %%
processDict = {'T2tt' : r'$\tilde{t} \, \tilde{t}, \tilde{t} \to t \chi$',
              'T2bbffff' : r'$\tilde{t} \, \tilde{t}, \tilde{t} \to b W^* \chi$',
              'T2bbWW' : r'$\tilde{t} \, \tilde{t}, \tilde{t} \to b W \chi$'}
def convertLabel(label):
    newlabel = label[:]
    #Replace txnames by process
    for txlabel,proc in processDict.items():
        newlabel = newlabel.replace(txlabel,proc) 
    #Remove off-shell Ws and Zs from ATLAS analyses (since they only appear in on-shell cases)
    if 'ATLAS' in newlabel:
        newlabel = newlabel.replace('W^{(*)} Z^{(*)}', 'W Z')
    return newlabel

# %%
#Merge with SModelS DataFrame
#dataDF = pd.read_pickle('sms_smodels_new.pcl')
#dataDF = pd.read_pickle('VLF_smodels.pcl')
dataDF = pd.read_pickle('Zp_ttbar_smodels.pcl')
#print(dataDF)
print(dataDF.columns.values.tolist()) #Print all columns names
# Out:
# ['filename', 'mass.5000001', 'mass.5000511', 'mass.5000512', 'mass.5000521', 'mass.9000002', 'mass.9000003', 'mass.9000004', 'width.5000001', 'width.5000511', 'width.5000512', 'width.5000521', 'width.9000002', 'width.9000003', 'width.9000004', 'xsec13TeV(fb).5000001', 'BRs.5000001.-6,6', 'BRs.5000001.-2,2', 'BRs.5000001.-1,1', 'pars.1', 'pars.2', 'pars.3', 'pars.4', 'pars.5', 'pars.6', 'pars.7', 'pars.8', 'pars.9', 'pars.10', 'pars.11', 'pars.12', 'pars.13', 'pars.14', 'pars.15', 'pars.16', 'pars.17', 'pars.18', 'pars.19', 'pars.20', 'pars.21', 'pars.22', 'pars.23', 'pars.24', 'pars.25', 'pars.26', 'pars.27', 'pars.28', 'pars.29', 'totalxsec13TeV(fb)', 'totalxsec8TeV(fb)', 'Total xsec for missing topologies (fb)', 'Total xsec for missing topologies with displaced decays (fb)', 'Total xsec for missing topologies with prompt decays (fb)', 'Total xsec for topologies outside the grid (fb)', 'OutputStatus.sigmacut', 'OutputStatus.minmassgap', 'OutputStatus.maxcond', 'OutputStatus.ncpus', 'OutputStatus.model', 'OutputStatus.promptwidth', 'OutputStatus.stablewidth', 'OutputStatus.checkinput', 'OutputStatus.doinvisible', 'OutputStatus.docompress', 'OutputStatus.computestatistics', 'OutputStatus.testcoverage', 'OutputStatus.combinesrs', 'OutputStatus.reportallsrs', 'OutputStatus.experimentalfeatures', 'OutputStatus.file status', 'OutputStatus.decomposition status', 'OutputStatus.warnings', 'OutputStatus.input file', 'OutputStatus.database version', 'OutputStatus.smodels version', 'ExptRes.result0.maxcond', 'ExptRes.result0.theory prediction (fb)', 'ExptRes.result0.upper limit (fb)', 'ExptRes.result0.expected upper limit (fb)', 'ExptRes.result0.TxNames', 'ExptRes.result0.FinalStates', 'ExptRes.result0.Mass (GeV)', 'ExptRes.result0.AnalysisID', 'ExptRes.result0.DataSetID', 'ExptRes.result0.AnalysisSqrts (TeV)', 'ExptRes.result0.lumi (fb-1)', 'ExptRes.result0.dataType', 'ExptRes.result0.r', 'ExptRes.result0.r_expected', 'ExptRes.result0.Width (GeV)', 'ExptRes.result1.maxcond', 'ExptRes.result1.theory prediction (fb)', 'ExptRes.result1.upper limit (fb)', 'ExptRes.result1.expected upper limit (fb)', 'ExptRes.result1.TxNames', 'ExptRes.result1.FinalStates', 'ExptRes.result1.Mass (GeV)', 'ExptRes.result1.AnalysisID', 'ExptRes.result1.DataSetID', 'ExptRes.result1.AnalysisSqrts (TeV)', 'ExptRes.result1.lumi (fb-1)', 'ExptRes.result1.dataType', 'ExptRes.result1.r', 'ExptRes.result1.r_expected', 'ExptRes.result1.Width (GeV)', 'ExptRes.result2.maxcond', 'ExptRes.result2.theory prediction (fb)', 'ExptRes.result2.upper limit (fb)', 'ExptRes.result2.expected upper limit (fb)', 'ExptRes.result2.TxNames', 'ExptRes.result2.FinalStates', 'ExptRes.result2.Mass (GeV)', 'ExptRes.result2.AnalysisID', 'ExptRes.result2.DataSetID', 'ExptRes.result2.AnalysisSqrts (TeV)', 'ExptRes.result2.lumi (fb-1)', 'ExptRes.result2.dataType', 'ExptRes.result2.r', 'ExptRes.result2.r_expected', 'ExptRes.result2.Width (GeV)']

# %% [markdown]
# #### Set r = 0 for points with no results

# %%
#Set points without results with r == 0
dataDF.fillna(value={'ExptRes.result0.r' : 0.0},inplace=True)
#Sort points according to r value:
dataDF = dataDF.sort_values(by=['ExptRes.result0.r'],ascending=False)

# %% [markdown]
# #### Define exclusions

# %%
#Add simple flag for excluded points:
newDF = dataDF.copy()
newDF['excludedLHC'] = dataDF['ExptRes.result0.r'] > 1.0/1.6

# %% [markdown]
# #### Add c*tau and deltaM columns

# %%
#newDF['ctau.5000006'] = 1.967e-16/dataDF['width.5000006']
newDF['xsecXBRtt'] = (dataDF['xsec13TeV(fb).5000001']*dataDF['BRs.5000001.-6,6']) / 1000.0
newDF['xsecXBRqq'] = (dataDF['xsec13TeV(fb).5000001']*(dataDF['BRs.5000001.-1,1'] + dataDF['BRs.5000001.-2,2'])) / 1000.0

# %% [markdown]
# ### Get points excluded:

# %%
dataDF = newDF
excluded = dataDF[dataDF['excludedLHC'] == True]
allowed = dataDF[(dataDF['excludedLHC'] == False)]

print('Total number of points = %i' %len(dataDF))
print('Total excluded (LHC) = %i'%(len(excluded)))
print('Total allowed = %i\n'%(len(allowed)))

# print('Total excluded (r > %1.2f) = %i'%(rscale,len(excludedSC)))
# print('Total allowed (r > %1.2f) = %i'%(rscale,len(allowedSC)))
# Out:
# Total number of points = 14840
# Total excluded (LHC) = 6952
# Total allowed = 7888

# %% [markdown]
# ### Split data frame by analyis/txname

# %%
allAnas = []
allTx = []
useDF = dataDF
anaIDcols = [c for c in useDF.columns if '.AnalysisID' in c]
txIDcols = [c for c in useDF.columns if '.TxNames' in c]
for c in anaIDcols:
    allAnas += useDF[c].values.tolist()
for c in txIDcols:
    allTx += useDF[c].values.tolist()

allAnas = [a for a in allAnas if isinstance(a,str)]
allAnas = sorted(list(set(allAnas)))
allTx = [tuple(a) for a in allTx if isinstance(a,list)]
allTx = sorted(list(set(allTx)))
anaDFs = {}
for a in allAnas:
    anaDFs[a] = {}
    newrowList = []
    for irow,row in useDF.iterrows():
        ires = [col for col in anaIDcols if (row[col] == a)]
        if not ires:
            continue
        ires = ires[0]
        ires = ires.rsplit('.',1)[0]
        newrow = { }
        for c in dataDF.columns:
            if not 'ExptRes.result' in c:
                newrow[c] = row[c]
            elif c.rsplit('.',1)[0] == ires:
                newrow[c.replace(ires,'ExptRes.result')] = row[c]
        newrowList.append(newrow)
    if len(newrowList) != 0:
        anaDFs[a] = pd.DataFrame.from_dict(newrowList)
    # for tx in allTx:
    #     newrowList = []
    #     for irow,row in useDF.iterrows():
    #         ires = [col for col in anaIDcols if ((row[col] == a)  and row[col.replace('AnalysisID','TxNames')] == list(tx))]
    #         if not ires:
    #             continue
    #         ires = min(ires).rsplit('.',1)[0]
    #         newrow = { }
    #         for c in dataDF.columns:
    #             if not 'ExptRes.result' in c:
    #                 newrow[c] = row[c]
    #             elif c.rsplit('.',1)[0] == ires:
    #                 newrow[c.replace(ires,'ExptRes.result')] = row[c]
    #         newrowList.append(newrow)
    #     if len(newrowList) != 0:
    #         anaDFs[a][tx] = pd.DataFrame.from_dict(newrowList)

# %% [markdown]
# ### Create analysis label for excluded points

# %%
anas = excluded['ExptRes.result0.AnalysisID'].value_counts()
anas.sort_values(inplace=True,ascending=False)

    
labels = []
for index, row in excluded.iterrows():
    ana = row['ExptRes.result0.AnalysisID']
    txList = sorted(row['ExptRes.result0.TxNames'])
    label = ana + ' (' + ','.join(txList) + ')'
    label = label.replace('off','') #Group together on and off-shell topologies
    labels.append(label)
excluded['label'] = labels
#print(excluded['label'])

# %%
nexcluded = [[len(excluded[excluded['label'] == label]),label] for label in excluded['label'].unique()]
nexcluded = sorted(nexcluded,reverse=True)
nexcluded = np.array(nexcluded)
for label in nexcluded[:,1]:
    print(label+': %i'%len(excluded[excluded['label'] == label]))
# Out:
# CMS-EXO-19-012 (TRV1jj): 3897
# ATLAS-EXOT-2019-03 (TRV1jj): 1906
# ATLAS-EXOT-2018-48 (TRV1tt): 1149

# %% [markdown]
# ### Define colors and plotting order

# %%
colors = sns.color_palette("Paired",len(excluded['label'].unique()))
colorsPink = sns.color_palette("colorblind",8)
colorDict = {'ATLAS-EXOT-2018-48 (TRV1tt)' : colorsPink[4], #light pink
             'ATLAS-EXOT-2019-03 (TRV1jj)' : 'red', #red
             'CMS-EXO-19-012 (TRV1jj)' : 'darkblue', #dark blue
             'ATLAS-SUSY-2018-12 (T2bbffff)' : 'darkgreen', #dark green
             'CMS-PAS-SUS-16-052 (T2bbWW)' : 'lightblue', #light blue
             'Other' : 'darkpurple' #dark purple
             }
#Define plotting order:
plottingOrder = nexcluded[:,1]
#Add other analyses
for ana in excluded['label'].unique():
    if not ana in plottingOrder:
        plottingOrder.append(ana)

# %% [markdown]
# ### Plot excluded points grouped by most excluding analysis

# %%
anas = excluded['label'].value_counts()
anas.sort_values(inplace=True,ascending=False)

plt.figure(figsize=(10,4))

x = allowed['mass.5000001']
y = allowed['xsecXBRtt']
# y = allowed['mass.5000012']
c_other = 'lightgray'
plt.scatter(x,y,color=c_other,label='All',s=60)

otherLabel = 'Others'
for ana in plottingOrder:
    x = excluded[excluded['label'] == ana]['mass.5000001']
    y = excluded[excluded['label'] == ana]['xsecXBRtt']
    if not ana in colorDict:
        color = colorDict['Other']        
        plt.scatter(x,y,color=color,label=otherLabel,s=90)
        otherLabel = None #suppress repeated label
    else:
        color = colorDict[ana]
        label = convertLabel(ana)
        plt.scatter(x,y,color=color,label=label,s=90)


lgd = plt.legend(loc=(1.01,0.2), framealpha=1.,fontsize=15)
plt.yscale('log')
plt.xlabel(r'$M_{\tilde{t}}$ (GeV)')
plt.ylabel(r'$\Delta M$ (GeV)')
plt.tight_layout()
# plt.savefig('stop_exclusion_deltaM.png')
plt.xlim(1500,5100)
# plt.ylim(0,1000)
plt.grid()
plt.show()

# %%
# --- Configuration ---
target_regime = 'topDom' 
# Only keep points where the top coupling is at least 20% larger than the jet coupling
dominance_margin = 1.0

contoursDictAna = {}

for ana in anaDFs:
    anaDF = anaDFs[ana]
    
    # 1. Standard Cleaning
    cleanDF = anaDF.dropna(subset=['mass.5000001', 'xsecXBRtt']).copy()
    cleanDF['ExptRes.result.r'] = cleanDF['ExptRes.result.r'].fillna(0)
    
    # 2. CREATE FILTERS
    # A. The 1% Width Condition
    cond_width = (cleanDF['width.5000001']/cleanDF['mass.5000001'] > 0.009) & \
                 (cleanDF['width.5000001']/cleanDF['mass.5000001'] < 0.011)
    
    # B. The Regime Condition
    cond_regime = cleanDF['filename'].str.contains(target_regime)
    
    # C. NEW: Dominance Threshold (The "Noise" Killer)
    # This ensures we only use points where g_t is clearly dominant
    # We use the DMINPUTS columns from your SModelS scan
    cond_threshold = cleanDF['pars.9'] > (cleanDF['pars.4'] * dominance_margin)
    
    # D. COMBINE
    final_mask = cond_width & cond_regime & cond_threshold
    
    # 3. Apply the combined filter
    x = cleanDF['mass.5000001'][final_mask]
    dm = cleanDF['xsecXBRtt'][final_mask]
    z = cleanDF['ExptRes.result.r'][final_mask]
    
    if len(x) < 10: continue

    # 4. Interpolate (LinearND handles the new sharp boundary perfectly)
    dm_log = np.log10(dm)
    xnew, ynew_log, znew = interpolateData(x, dm_log, z)

    
    if xnew is None:
        continue
        
    # 5. Get Contours
    cValues = sorted([1., 1./1.5])
    # Extract in log-space for stability, then convert back to linear if needed
    cList = getContours(xnew, ynew_log, znew, cValues)
    
    if len(cList) > 0:
        contoursDictAna[ana] = cList

# %%
# --- Configuration ---
target_regime = 'topDom' 
# Only keep points where the top coupling is at least 20% larger than the jet coupling
dominance_margin = 1.05

# 1. Standard Cleaning
cleanDF = dataDF.dropna(subset=['mass.5000001', 'xsecXBRtt']).copy()
cleanDF['ExptRes.result0.r'] = cleanDF['ExptRes.result0.r'].fillna(0)

# 2. CREATE FILTERS
# A. The 1% Width Condition
cond_width = (cleanDF['width.5000001']/cleanDF['mass.5000001'] > 0.009) & \
             (cleanDF['width.5000001']/cleanDF['mass.5000001'] < 0.011)

# B. The Regime Condition
cond_regime = cleanDF['filename'].str.contains(target_regime)

# C. NEW: Dominance Threshold (The "Noise" Killer)
# This ensures we only use points where g_t is clearly dominant
# We use the DMINPUTS columns from your SModelS scan
cond_threshold = cleanDF['pars.9'] > (cleanDF['pars.4'] * dominance_margin)

# D. COMBINE
final_mask = cond_width & cond_regime & cond_threshold

# 3. Apply the combined filter
x = cleanDF['mass.5000001'][final_mask]
dm = cleanDF['xsecXBRtt'][final_mask]
z = cleanDF['ExptRes.result0.r'][final_mask]

# ---------------------------------------------------------
# Extract & Normalize Data
# ---------------------------------------------------------
x_raw = cleanDF['mass.5000001'][final_mask].values
y_log_raw = np.log10(cleanDF['xsecXBRtt'][final_mask].values)
z_vals = cleanDF['ExptRes.result0.r'][final_mask].values

# We scale X and Y to be between 0 and 1 so the interpolator treats them equally
x_min, x_max = x_raw.min(), x_raw.max()
y_min, y_max = y_log_raw.min(), y_log_raw.max()

x_norm = (x_raw - x_min) / (x_max - x_min)
y_norm = (y_log_raw - y_min) / (y_max - y_min)

# 2. Create the Interpolator on scaled data
interp = LinearNDInterpolator(list(zip(x_norm, y_norm)), z_vals)

# 3. Create the dense grid and normalize IT too
xi = np.linspace(1500, 5000, 400)
yi_log = np.linspace(-5, 0.5, 400)
X, Y_log = np.meshgrid(xi, yi_log)

X_norm = (X - x_min) / (x_max - x_min)
Y_norm = (Y_log - y_min) / (y_max - y_min)

# 4. Apply Interpolation
Z = interp(X_norm, Y_norm)

# ---------------------------------------------------------
# NEW FIX: CROP THE CONVEX HULL ARTIFACT
# ---------------------------------------------------------
# 1. Create a DataFrame of just the raw coordinates
df_boundary = pd.DataFrame({'x': x_raw, 'y': y_log_raw})

# 2. Find the absolute highest cross-section (Y) for every single Mass (X) column
upper_envelope = df_boundary.groupby('x')['y'].max().reset_index()

# 3. Create a mathematical function that traces this jagged upper roof
boundary_func = interp1d(upper_envelope['x'], upper_envelope['y'], kind='linear', fill_value='extrapolate')

# 4. Apply the mask!
# If any point in our dense grid (Y_log) is physically higher than the true data boundary at that mass (X), delete it.
Z[Y_log > boundary_func(X)] = np.nan

# ---------------------------------------------------------
# 5. Extract Contours & Convert to Linear
# ---------------------------------------------------------
csv_data = []

# We create a hidden plot just to generate the contours mathematically
fig_tmp, ax_tmp = plt.subplots()
# Pass Z directly. The tool perfectly understands and respects NaNs.
cs = ax_tmp.contour(xi, yi_log, Z, levels=cValues)

# Loop through the contour levels (e.g., 0.67 and 1.0)
for i, cV in enumerate(cValues):
    segs = cs.allsegs[i] # Get all individual line segments for this level
    
    for poly in segs:
        # Skip tiny noise artifacts (segments with fewer than 3 points)
        if len(poly) < 3: 
            continue 
            
        # Add the points of this segment to the CSV list
        for point in poly:
            csv_data.append({
                'r_value': cV,
                'mZp_GeV': point[0],
                'xsecXBR_pb': 10**(point[1]) # Convert log-y back to linear pb here!
            })
            
        # --- THE "PEN UP" TRICK ---
        # Add a blank row after every segment. When you plot this CSV later,
        # plt.plot() will see the NaN, lift its pen, and start a fresh line 
        # for the next segment, preventing the "scribble" effect!
        csv_data.append({
            'r_value': cV,
            'mZp_GeV': np.nan,
            'xsecXBR_pb': np.nan
        })

plt.close(fig_tmp) # Close the hidden figure

# =========================================================
# 6. Save to CSV
# =========================================================
if csv_data:
    df_contours = pd.DataFrame(csv_data)
    csv_filename = f"Exclusion_Contours_{target_regime}_tt.csv"
    df_contours.to_csv(csv_filename, index=False)
    print(f"Successfully saved {len(df_contours)} contour points to '{csv_filename}'.")
else:
    print("No contours were found to save.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 69
#      66 upper_envelope = df_boundary.groupby('x')['y'].max().reset_index()
#      68 # 3. Create a mathematical function that traces this jagged upper roof
# ---> 69 boundary_func = interp1d(upper_envelope['x'], upper_envelope['y'], kind='linear', fill_value='extrapolate')
#      71 # 4. Apply the mask!
#      72 # If any point in our dense grid (Y_log) is physically higher than the true data boundary at that mass (X), delete it.
#      73 Z[Y_log > boundary_func(X)] = np.nan
#
# NameError: name 'interp1d' is not defined

# %%
plt.figure(figsize=(9, 7))
plt.scatter(x,dm,c=z,cmap=cm,s=30,vmin=0.,vmax=2.)
plt.colorbar(label=r'$r$-value')
plt.xlabel(r'$m_{Z^\prime}$ (GeV)')
plt.ylabel(r'$\sigma(pp\to Z^\prime)\times\rm{BR}(Z^\prime \to t\bar{t})$ (pb)')
#plt.axvline(x = 2200)
plt.xlim(1400.,5100.)
#plt.ylim(1e-5, 10.0)
plt.yscale('log')
#plt.scatter([225.0], [70.0])
plt.show()

# %%
# ---------------------------------------------------------
# Plotting
# ---------------------------------------------------------
plt.figure(figsize=(10, 8))
ynew_linear = 10**yi_log
cValues = sorted([1./1.5])

# Use 'shading=auto' to ensure sharp boundaries
mesh = plt.pcolormesh(xi, ynew_linear, Z, cmap=cm, vmin=0, vmax=2, shading='auto')
plt.colorbar(mesh, label=r'$r$-value')

# Plot the contours using the linear axes
contours = plt.contour(xi, ynew_linear, Z, levels=cValues, colors='black', linestyles='dashed')
plt.clabel(contours, inline=True, fontsize=14, fmt={1.0: 'r=1.0', 1./1.5: 'r=0.67'})

plt.yscale('log')
plt.xlim(1500, 5000)
plt.ylim(1e-5, 0.2)
plt.xlabel(r'$m_{Z^\prime}$ (GeV)')
plt.ylabel(r'$\sigma \times \rm{BR}$ (pb)')
#plt.title(f'Top Dominant Regime ({ana})')
plt.show()

# %% [markdown]
# #Define the conditions for the points to remove
# #cond1 = (dataDF['xsecXBRtt'] >= 11)
#
# #Filter the DataFrame to keep points that dont (~) match the conditions
# #filteredDF = dataDF[~cond1 ]
#
#
# #x = filteredDF['mass.5000001']
# #dm = filteredDF['xsecXBRtt']
# #z = filteredDF['ExptRes.result0.r']
#
# # Interpolate to create more points using the clean data
# xnew, ynew, znew = interpolateData(x, dm, z)
#
# # Get contours
# cValues = sorted([1., 1./1.5])
# contoursDict = getContours(xnew, ynew, znew, cValues)
#
#
# target_val = 1./1.5
# closest_key = min(contoursDict.keys(), key=lambda k: abs(k - target_val))
#
# cList = contoursDict[closest_key]
#
# if len(cList) > 0:
#     contoursDictAna[ana] = cList

# %%
plt.figure(figsize=(9, 7))
plt.imshow(znew.T, extent=[x.min(),x.max(), (10**ynew_log).min(), (10**ynew_log).max()], origin='lower',
                  cmap=cm,aspect='auto',vmin=0,vmax=2)
plt.colorbar(label=r'$r$-value')
plt.xlabel(r'$m_{T}$ (GeV)')
plt.ylabel(r'$\Delta M$ (GeV)')
contours = plt.contour(xnew, 10**ynew_log, znew, cValues, colors='black',linestyles='dashed')
plt.clabel(contours, inline=True, fontsize=18)
plt.yscale('log')
plt.title('Direct Searches')
#plt.yscale('log')
plt.xlabel(r'$m_{Z^\prime}$ (GeV)')
plt.ylabel(r'$\sigma(pp\to Z^\prime)\times\rm{BR}(Z^\prime \to t\bar{t})$ (pb)')
#plt.ylim(1e-4,10.)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.imshow(znew.T, extent=[x.min(),x.max(), dm.min(), dm.max()], origin='lower',
                  cmap=cm,aspect='auto',vmin=0,vmax=2)
plt.colorbar(label=r'$r$-value')
plt.xlabel(r'$m_{T}$ (GeV)')
plt.ylabel(r'$\Delta M$ (GeV)')
contours = plt.contour(xnew, ynew, znew, cValues, colors='black',linestyles='dashed')
plt.clabel(contours, inline=True, fontsize=18)
# plt.yscale('log')
plt.title('Direct Searches')
#plt.yscale('log')
plt.xlabel(r'$m_{Z^\prime}$ (GeV)')
plt.ylabel(r'$\sigma(pp\to Z^\prime)\times\rm{BR}(Z^\prime \to t\bar{t})$ (pb)')
#plt.ylim(0.,10.)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Save contour curves to text files

# %%
fname = 'SModelS_contours_Zp_ttbar.csv'
#saveContours(contoursDict,fname,header='mPsiT_GeV,deltaM_GeV')
saveContours(contoursDict,fname,header='mZp_GeV,xsecXBR_pb')
# Out:
# Contours saved to SModelS_contours_Zp_ttbar.csv

# %%
import os
import glob
import matplotlib.pyplot as plt

# ---------------------------------------------------------
# 1. Configuration
# ---------------------------------------------------------
slha_dir = "/home/vinicius/EFT_ToyModel/processFolders/Zp_SLHAs/"
slha_files = glob.glob(os.path.join(slha_dir, "*.slha"))

masses = []
sigma_br = []
regimes = [] 

# ---------------------------------------------------------
# 2. Parsing Logic
# ---------------------------------------------------------
print(f"Found {len(slha_files)} SLHA files. Parsing...")

for filepath in slha_files:
    mass = None
    xsec = None
    br_top = None
    in_zp_decay = False
    
    with open(filepath, 'r') as f:
        lines = f.readlines()
        
    for line in lines:
        # 1. Extract Mass from BLOCK MASS
        if line.strip().startswith("5000001") and "my1" in line:
            parts = line.split()
            mass = float(parts[1])
            
        # 2. Extract Cross-section
        elif "ufo2slha" in line:
            parts = line.split()
            xsec = float(parts[6])
            
        # 3. Extract BR(Z' -> tt)
        elif line.startswith("DECAY") and "5000001" in line:
            in_zp_decay = True
            continue
        elif line.startswith("DECAY"):
            in_zp_decay = False
            continue
            
        if in_zp_decay and not line.strip().startswith("#"):
            parts = line.split()
            if len(parts) >= 4:
                try:
                    pids = [int(parts[2]), int(parts[3])]
                    if 6 in pids and -6 in pids:
                        br_top = float(parts[0])
                except ValueError:
                    pass
                    
    # Only append if we successfully found all three parameters
    if mass is not None and xsec is not None and br_top is not None:
        masses.append(mass)
        sigma_br.append(xsec * br_top)
        
        # Tag the regime for color-coding the plot
        if "topDom" in filepath:
            regimes.append("topDom")
        elif "jetDom" in filepath:
            regimes.append("jetDom")
        else:
            regimes.append("Unknown")

print(f"Successfully parsed {len(masses)} points. Generating plot...")

# ---------------------------------------------------------
# 3. Plotting
# ---------------------------------------------------------
plt.figure(figsize=(10, 8))

# Separate points by regime for visualization
for regime_type, color, marker in [("topDom", "blue", "o"), ("jetDom", "red", "x")]:
    m_plot = [m for m, r in zip(masses, regimes) if r == regime_type]
    s_plot = [s for s, r in zip(sigma_br, regimes) if r == regime_type]
    plt.scatter(m_plot, s_plot, c=color, marker=marker, label=regime_type, alpha=0.6)

plt.yscale('log')
plt.xlabel(r'$m_{Z^\prime}$ (GeV)', fontsize=14)
plt.ylabel(r'$\sigma(pp \to Z^\prime) \times \rm{BR}(Z^\prime \to t\bar{t})$ (pb)', fontsize=14)
plt.title('SLHA Validation: Raw Parsed Grid Points', fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, which="both", ls="--", alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Found 14501 SLHA files. Parsing...
# Successfully parsed 14501 points. Generating plot...

# %%
import glob
import pandas as pd

# 1. Check for files killed by sigmacut
total_slhas = len(glob.glob("/home/vinicius/EFT_ToyModel/processFolders/Zp_SLHAs/*.slha"))
total_rows = len(anaDF)

print(f"Total SLHA files generated: {total_slhas}")
print(f"Total rows in SModelS output: {total_rows}")
print(f"Points killed by sigmacut: {total_slhas - total_rows}")
print("-" * 40)

# 2. Check for NaN r-values
# (Check your exact column name, sometimes it is 'ExptRes.result0.r' or just 'ExptRes.result.r')
r_col = 'ExptRes.result.r' 

if r_col in anaDF.columns:
    nan_count = anaDF[r_col].isna().sum()
    valid_count = anaDF[r_col].notna().sum()
    
    print(f"Points with a calculated r-value: {valid_count}")
    print(f"Points too weak for an r-value (NaN): {nan_count}")
    print("-" * 40)
    
    # Let's see the physical boundaries of the NaNs
    if nan_count > 0:
        nan_df = anaDF[anaDF[r_col].isna()]
        valid_df = anaDF[anaDF[r_col].notna()]
        
        print(f"Highest cross-section that returned NaN: {nan_df['xsecXBRtt'].max():.2e} pb")
        print(f"Lowest cross-section that got an r-value: {valid_df['xsecXBRtt'].min():.2e} pb")
else:
    print(f"Column {r_col} not found in the DataFrame!")
# Out:
# Total SLHA files generated: 1951
# Total rows in SModelS output: 1866
# Points killed by sigmacut: 85
# ----------------------------------------
# Points with a calculated r-value: 1866
# Points too weak for an r-value (NaN): 0
# ----------------------------------------
